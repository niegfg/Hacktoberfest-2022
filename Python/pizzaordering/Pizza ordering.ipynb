# %%
pricem = {'thin': 4.00,'thick': 6.50,'wood_fired': 8.50,'cheese': 0.50,'tomato': 0.75,'mushrooms': 0.75,'peperoni': 0.50,'onions': 0.25,'black_olives': 0.75,'green_peppers': 0.50,'anchovies': 0.25,'garlic': 0.50,'ham':1.50,'bacon':1.25}

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

def ptoppingct():
    print('\nPricing:\n\tThin \t$4.00')
    print('\n\tThick \t$6.50')
    print('\n\tWood Fired \t$8.50')
    print('\n\tCustom calculated based on crust type.\n')
    print('\tTotal:\t\t${:4.2f}'.format(total) + '\n')
    
def ptoppingc():
    print('\nPricing:')
    print('\n\tChedder\n\tColby\n\tEdam\n\tEmmental\n\tGruyere\n\tMozzarella\n\tProvolone\n\tRicotta')
    print('\tEach cheese costs $0.50 (regardless of style).\n')
    print('\tTotal:\t\t${:4.2f}'.format(total) + '\n')

def ptopping1():
    print('\nPricing:\n\tTomato \t$0.75')
    print('\tMushrooms \t$0.75')
    print('\tPeperoni \t$0.50')
    print('\tOnions \t$0.25')
    print('\tBlack Olives \t$0.75')
    print('\tGreen Peppers \t$0.50')
    print('\tAnchovies  \t$0.25')
    print('\tGarlic \t$0.50')
    print('\tHam  \t$1.50')
    print('\tBacon \t$1.25')
    print('\tTotal:\t\t${:4.2f}'.format(total) + '\n')
    
for word in 'Welcome to Fat Pizza'.split():
    print(f'{word.capitalize():=^65}')
print("\n")
import time
time.sleep(0.5)
print(color.UNDERLINE+'While making selections please enter word in bracket\n'+color.END)
time.sleep(0.5)
print(color.UNDERLINE+'ex: Mushrooms(m) -> Enter m in the textbox\n'+color.END)
time.sleep(0.5)
print(color.UNDERLINE+'Only one selection allowed at the input\n'+color.END)
time.sleep(1.3)
ordering = True
this_pizza = 0
            
def pizza_number(customer_name):
    while True:  
        try:
            pizza_count = 0
            pizza_count = int(input('How many pizza you want to order today\t'+ customer_name.upper() +'?\n\tyou can order maximum 10 pizza\t'))
            if pizza_count > 0 and pizza_count <= 10:
                print(color.PURPLE+'\nYou are ordering '+ str(pizza_count)  +' pizza'+color.END)
                return int(pizza_count);
            else:
                print(color.RED+"\nYou must enter the number between 1 to 3! Try again."+color.END)
        except ValueError:
             print(color.RED+"\nYou must enter the number between 1 to 10! Try again."+color.END)
    else:
        print(color.RED+"\nYou must pick pizza grater than 0 and less than 10."+color.END)
        
def cheese_number():
    while True:  
        try:
            cheese_count = 0
            cheese_count = int(input('How many cheese you want to add on pizza?\n\tyou can add maximum 3 cheese\t'))
            if cheese_count > 0 and cheese_count <= 3:
                print(color.PURPLE+'\nYou have selected \t'+ str(cheese_count) +'\tcheese on this pizza select from below list'+color.END)
                return int(cheese_count);
            else:
                print(color.RED+"\nYou must enter the number between 1 to 3! Try again."+color.END)
        except ValueError:
             print(color.RED+"\nYou must enter the number between 1 to 3! Try again."+color.END)
    else:
        print(color.RED+"\nYou must enter the number between 1 to 3! Try again."+color.END)
        

def choose_crust():
    while True:  
        crust_type = ''
        crust_type = input(color.PURPLE+'\n\tThin(t)\n\tThick(th)\n\tWood Fired(w)\t'+color.END).lower()
        if crust_type in ('t', 'th', 'w', 'Thin', 'Thick', 'Wood Fired'):
            return crust_type
        else:
            print(color.RED+'Please Make selection using t,th or w'+color.END)
            
def choose_cheese():
    while True:  
        cheese_type = ''
        print(color.PURPLE+'\n\tChedder(ch)\n\tColby(co)\n\tEdam(ed)\n\tEmmental(em)\n\tGruyere(g)\n\tMozzarella(m)\n\tProvolone(p)\n\tRicotta(r)\t'+color.END)
        crust_type = input('Please choose from above Cheese type').lower()
        if crust_type in ('ch', 'co', 'ed', 'em', 'g', 'm','p', 'r'):
            return crust_type
        else:
            print(color.RED+'Please Make selection from listed items'+color.END)
            
def choose_topping():
    while True:  
        topping_type = ''
        print(color.PURPLE+'\tMushrooms(m)\t$0.75\n\tPeperoni(p)\t$0.50\n\tOnions(o)\t$0.25\n\tBlack Olives(bo)\t$0.75\n\tGreen Peppers(gp)\t$0.50\n\tAnchovies(a)\t$0.25\n\tGarlic(g)\t$0.50\n\tHam(h)\t$1.50\n\tBacon(b)\t$1.25\t'+color.END)
        print(color.GREEN+'\tenter fin to end the selection'+color.END)
        topping_type = input('Please choose from above toppings.').lower()
        if topping_type in ('m','p','o','bo','gp','a','g','h','b','fin'):
            return topping_type
        else:
            print(color.RED+'Please Make selection from listed items'+color.END)
            
            
while ordering:
    order = []
    pizza_total = [] 
    customer_name = input(color.BLUE+'May i have your name please?'+color.END)
    pizza_no = 0
    pizza_no = int(pizza_number(customer_name))    

    while this_pizza < pizza_no:
            calc = 0
            order.append([])
            pizza_total.append([])
            order[this_pizza].append(color.BOLD+'Pizza ' + str(this_pizza+1) +'\n'+color.END)
            print(color.BLUE+'\nPlease pick Crust type'+color.END)
            Crust = ''
           
            Crust = choose_crust()
            if Crust.lower() == 't':
                calc = pricem['thin'] 
                order[this_pizza].append('Crust\t Thin ${:4.2f}'.format(pricem['thin'] ) + '\n')
                print(color.BLUE+'\n\tThin Crust selected.'+color.END)
            elif Crust.lower() == 'th':
                calc =  pricem['thick']
                order[this_pizza].append('Crust\t Thick ${:4.2f}'.format(pricem['thick'] ) + '\n')
                print(color.BLUE+'\n\tThick Crust selected.'+color.END)
            elif Crust.lower() == 'w':
                calc = pricem['wood_fired']
                order[this_pizza].append('Crust\t Wood Fired ${:4.2f}'.format(pricem['wood_fired'] ) + '\n')
                print(color.BLUE+'\n\tWood Fired Crust selected.'+color.END)
            
            
            cheese_added = 0
            cheese_no = 0
            cheese_no = int(cheese_number())
            while cheese_added < cheese_no:
                Cheese = ''
                Cheese = choose_cheese()
                if Cheese.lower() == 'ch':
                    order[this_pizza].append('Cheese\t Chedder ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tChedder Cheese selected.'+color.END)
                elif Cheese.lower() == 'co':
                    order[this_pizza].append('Cheese\t Colby ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tColby Cheese selected.'+color.END)
                elif Cheese.lower() == 'ed':
                    order[this_pizza].append('Cheese\t Edam ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tEdam Cheese selected.'+color.END)
                elif Cheese.lower() == 'em':
                    order[this_pizza].append('Cheese\t Emmental ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tEmmental Cheese selected.'+color.END)
                elif Cheese.lower() == 'g':
                    order[this_pizza].append('Cheese\t Gruyere ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tGruyere Cheese selected.'+color.END)
                elif Cheese.lower() == 'm':
                    order[this_pizza].append('Cheese\t Mozzarella ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tMozzarella Cheese selected.'+color.END)
                elif Cheese.lower() == 'p':
                    order[this_pizza].append('Cheese\t Provolone ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tProvolone Cheese selected.'+color.END)
                elif Cheese.lower() == 'r':
                    order[this_pizza].append('Cheese\t Ricotta ${:4.2f}'.format(pricem['cheese'] ) + '\n')
                    print(color.BLUE+'\n\tRicotta Cheese selected.'+color.END)
                calc = calc + pricem['cheese'] 
                cheese_added = cheese_added + 1
            
            print("\nplease select topping from below list. Maximum 6 toppings allowed per pizza")
            topping_added = 0
            while topping_added < 6:
                topping_added = topping_added + 1
                topping = ''
                Topping = choose_topping()
                if Topping.lower() == 'm':
                    calc = calc + pricem['mushrooms'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Mushrooms ${:4.2f}'.format(pricem['mushrooms'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Mushrooms selected.'+color.END)
                elif Topping.lower() == 'p':
                    calc = calc + pricem['peperoni'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Peperoni ${:4.2f}'.format(pricem['peperoni'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Peperoni selected.'+color.END)
                elif Topping.lower() == 'o':
                    calc = calc + pricem['onions'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Onions ${:4.2f}'.format(pricem['onions'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Onions selected.'+color.END)
                elif Topping.lower() == 'bo':
                    calc = calc + pricem['black_olives'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Black Olives ${:4.2f}'.format(pricem['black_olives'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Black Olives selected.'+color.END)
                elif Topping.lower() == 'gp':
                    calc = calc + pricem['green_peppers'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Green Peppers ${:4.2f}'.format(pricem['green_peppers'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Green Peppers selected.'+color.END)
                elif Topping.lower() == 'a':
                    calc = calc + pricem['anchovies'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Anchovies ${:4.2f}'.format(pricem['anchovies'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Anchovies selected.'+color.END)
                elif Topping.lower() == 'g':
                    calc = calc + pricem['garlic'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Garlic ${:4.2f}'.format(pricem['garlic'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Garlic selected.'+color.END)
                elif Topping.lower() == 'h':
                    calc = calc + pricem['ham'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Ham ${:4.2f}'.format(pricem['ham'] ) + '\n')
                    print(color.BLUE+'\n\ttopping Ham selected.'+color.END)
                elif Topping.lower() == 'b':
                    calc = calc + pricem['bacon'] 
                    order[this_pizza].append('Topping '+ str(topping_added) +'\t Bacon ${:4.2f}'.format(pricem['bacon'] ) + '\n')
                    print(color.BLUE+'\n\ttopping bacon selected.'+color.END)
                elif Topping.lower() == 'fin':
                    print(color.BLUE+'\n\tTopping selection over'+color.END)
                    break
                    
            else:
                print(color.RED+'Maximum 6 topping is allowed per pizza'+color.END)
        
            pizza_total[this_pizza] = calc
            order[this_pizza].append(color.UNDERLINE+'Total of pizza '+ str(this_pizza + 1) + ' : ${:4.2f}'.format(calc)+color.END)
            this_pizza = this_pizza + 1    
            print(color.BLUE+str(this_pizza)+' pizza added'+color.END)
            
    else:
        tot = 0
        print(color.BLUE+'\nThank you for your order '+ customer_name+color.END)
        print(color.BLUE+'\nYour order is :'+color.END)
        count = 1
        for i in range(len(order)):
            for j in range(len(order[i])):
                print(order[i][j])
                print('-------------------------------------------------------')
            count = count + 1
            
        tot = sum(pizza_total)    
        print(color.BOLD+'Grand total is: ${:4.2f}'.format(tot)+color.END)
            
        
    cont = input(color.BLUE+'Would you like to do next order? please enter Y/N'+color.END)
    if cont.upper() == 'Y':
        this_pizza = 0
    elif cont.upper() == 'N':
        print('\nThank you!')
        break
    else:
        print('\nBye!.')
        break
                   
ordering = False
